# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
fig = plt.figure()
fig.add_axes([0,0,1,1])
fig.add_axes([.1,.1,.9,.9])
fig.add_axes([.2,.2,.8,.8])
fig.add_axes([.3,.3,.7,.7])
fig.add_axes([.4,.4,.6,.6])
fig.add_axes([.5,.5,.5,.5])
fig.add_axes([.6,.6,.4,.4])
fig.add_axes([.7,.7,.3,.3])
fig.add_axes([.8,.8,.2,.2])
fig.add_axes([.9,.9,.1,.1])
